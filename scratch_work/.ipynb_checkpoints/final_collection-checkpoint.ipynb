# %% [markdown]
# # Data Collection

# %%
import requests
from bs4 import BeautifulSoup

# converts profile page to list of line strings
def scrape_profile(profile_html):
    
    teacher = requests.get(profile_html)
    teacher_soup = BeautifulSoup(teacher.content, "html.parser")
    return teacher_soup.find_all(text = True)

# %%
# returns a list of classes taught
# by the teacher in the profile
def get_classes(data):
    
    # check for hidden/removed profiles
    if(data[110] == 
       "\nYou have requested an invalid professor evaluation; this could be because:\n"):
        return (None, 0)
    
    # check for N/A total scores (can not be used for machine learning model)
    # this also changes the offset values
    if(weird_na[118][0:3] == 'N/A'):
        return (None, 0)
    
    classes = []
    i= 133; 
    
    first_class = data[133]
    classes.append(first_class)
    next_class = data[137]
    
    while(next_class != '\n'):
        classes.append(next_class)
        i += 4
        next_class = data[i]
    
    if(len(classes) == 1):
        return (classes, i + 7)
    
    return(classes, i + 3)

# %%
# collect the review information here
import pandas as pd

def get_reviews(data, class_list, review_index):
    
    standings = ["Freshman", "Sophomore", "Junior", "Senior", "5th Year Senior", "5th/6th Year Senior", "Graduate Student"]
    
    rank = { "Freshman": 0, "Sophomore": 1, "Junior": 2, "Senior": 3, "5th Year Senior": 4, "5th/6th Year Senior": 4, "Graduate Student": 5}
    
    grades = { 'A': 4, 'B': 3, 'C': 2, 'D': 1, 'F': 0, 'N/A': None, 'Credit': None, 'No Credit': None, 'Withdrawn': None }
    
    reviews = { 'class': [], 'class_abrv': [], 'class_number': [], 
               'teacher_name': [], 'teacher_field': [], 'teacher_rating': [], 'teacher_difficulties': [], 'teacher_presentaion': [],
               'student_standing': [], 'student_rank': [], 'student_grade': [], 'student_gpa': [], 'student_major': [], 
               'review_month': [], 'review_year': [], 'review_content': [] }
    
    while(review_index < len(data)):
        
        # class information
        if(data[review_index] in class_list):
            reviews["class"].append(data[review_index])
            review_index += 3
        else:
            reviews["class"].append(reviews["class"][-1])
        
        student_class = reviews["class"][-1].split()
        reviews["class_abrv"].append(student_class[0])
        reviews["class_number"].append(int(student_class[1]))
        
        # teacher information
        reviews["teacher_name"].append(data[111])
        reviews["teacher_field"].append(data[117])
        reviews["teacher_rating"].append(float(data[118].split()[-1][0:4]))
        reviews["teacher_difficulties"].append(float(data[120].split()[-1])) # recognizes student difficulties
        reviews["teacher_presentaion"].append(float(data[121].split()[-1]))  
        
        # student information
        standing = data[review_index].replace("\n", '')
        reviews["student_standing"].append(standing)
        reviews["student_rank"].append(rank[standing])
        grade_letter = data[review_index + 1].replace("\n", '')
        reviews["student_grade"].append(grade_letter)
        reviews["student_gpa"].append(grades[grade_letter])
        reviews["student_major"].append(data[review_index + 2].replace("\n", ''))
        
        # review information
        time = data[review_index + 3].replace("\n", '').split()
        reviews["review_month"].append(time[0])
        reviews["review_year"].append(int(time[1]))
        
        review_index += 6 # offset to the beginning of the review

        review = ""       # default review is blank to account for empty reviews
        
        review_append = data[review_index].replace("\n",'')

        while((review_append not in class_list) and (review_append not in standings)):    #reviews are deliminated by class name
            
            if(review_append != ""):
                review = review + review_append
                
            review_index += 1
            
            if(review_index == (len(data) - 1)):
                reviews["review_content"].append(review)
                return pd.DataFrame(data = reviews)
            
            review_append = data[review_index].replace("\n",'')

        reviews["review_content"].append(review)

# %%
# returns a dataframe of a Polyrating's profile page
def get_profile_df(profile_html):

    teacher_data = scrape_profile(profile_html)
    (class_list, next_index) = get_classes(teacher_data)
    if(next_index == 0):  # handles hidden pages
        return None
    return get_reviews(teacher_data, class_list, next_index)

# %% [markdown]
# ## Example Profile Pages: Severus Snape

# %%
snape = get_profile_df("http://polyratings.com/eval.php?profid=3485")

# %%
snape
# Out:
#        class class_abrv  class_number  \
# 0   CHEM 101       CHEM           101
# 1   CHEM 110       CHEM           110
# 2   CHEM 124       CHEM           124
# 3   CHEM 124       CHEM           124
# 4   CHEM 125       CHEM           125
# 5   CHEM 125       CHEM           125
# 6   CHEM 129       CHEM           129
# 7   CHEM 202       CHEM           202
# 8   CHEM 211       CHEM           211
# 9   CHEM 216       CHEM           216
# 10  CHEM 242       CHEM           242
# 11  CHEM 394       CHEM           394
#
#                                        review_content review_month  \
# 0                        Snape, Snape, Severus Snape.          May
# 1   This professor is the most amazing teacher in ...          Mar
# 2   I tried really hard in his class but he seemed...          May
# 3   Very cramped handwriting, difficult to read on...          Jan
# 4   Coming in to the class I had heard some things...          Jan
# 5   I really wanted to get him for defense against...          May
# 6   Prof. Snape knows his chemistry, but seems per...          Jun
# 7   Professor Snape is a fantastic professor. Bare...          Jan
# 8   He can teach you how to bewitch the mind, and ...          Mar
# 9                                 I miss him. Always.          Jan
# 10  Professor Snape really knows his stuff. At fir...          Jan
# 11  At first he was really scary and intimidating....          Feb
#
#     review_year  student_gpa student_grade       student_major  student_rank  \
# 0          2014          3.0             B          General Ed             0
# 1          2014          4.0             A            Elective             0
# 2          2015          1.0             D    Required (Major)             0
# 3          2018          2.0             C  Required (Support)             0
# 4          2015          2.0             C            Elective             1
# 5          2016          3.0             B    Required (Major)             1
# 6          2015          2.0             C  Required (Support)             0
# 7          2018          4.0             A          General Ed             1
# 8          2014          3.0             B          General Ed             0
# 9          2016          3.0             B    Required (Major)             1
# 10         2016          1.0             D          General Ed             1
# 11         2014          NaN           N/A    Required (Major)             0
#
#    student_standing  teacher_difficulties                 teacher_field  \
# 0          Freshman                  2.33    Chemistry and Biochemistry
# 1          Freshman                  2.33    Chemistry and Biochemistry
# 2          Freshman                  2.33    Chemistry and Biochemistry
# 3          Freshman                  2.33    Chemistry and Biochemistry
# 4         Sophomore                  2.33    Chemistry and Biochemistry
# 5         Sophomore                  2.33    Chemistry and Biochemistry
# 6          Freshman                  2.33    Chemistry and Biochemistry
# 7         Sophomore                  2.33    Chemistry and Biochemistry
# 8          Freshman                  2.33    Chemistry and Biochemistry
# 9         Sophomore                  2.33    Chemistry and Biochemistry
# 10        Sophomore                  2.33    Chemistry and Biochemistry
# 11         Freshman                  2.33    Chemistry and Biochemistry
#
#       teacher_name  teacher_presentaion  teacher_rating
# 0   Snape, Severus                 3.33            3.17
# 1   Snape, Severus                 3.33            3.17
# 2   Snape, Severus                 3.33            3.17
# 3   Snape, Severus                 3.33            3.17
# 4   Snape, Severus                 3.33            3.17
# 5   Snape, Severus                 3.33            3.17
# 6   Snape, Severus                 3.33            3.17
# 7   Snape, Severus                 3.33            3.17
# 8   Snape, Severus                 3.33            3.17
# 9   Snape, Severus                 3.33            3.17
# 10  Snape, Severus                 3.33            3.17
# 11  Snape, Severus                 3.33            3.17

# %% [markdown]
# ## Edge Case Example: One Review

# %%
get_profile_df("http://polyratings.com/eval.php?profid=468")
# Out:
#       class class_abrv  class_number  \
# 0  MATE 128       MATE           128
#
#                                       review_content review_month  \
# 0  What the guy/gal below said. Amen. I too took ...          Nov
#
#    review_year  student_gpa student_grade student_major  student_rank  \
# 0         2016            4             A      Elective             3
#
#   student_standing  teacher_difficulties             teacher_field  \
# 0           Senior                   0.0    Mechanical Engineering
#
#         teacher_name  teacher_presentaion  teacher_rating
# 0  Mussulman, Ronald                  1.0             2.0

# %% [markdown]
# ## Large Profile (106 Reviews)

# %%
get_profile_df("http://polyratings.com/eval.php?profid=482")[-10: -1]
# Out:
#                                         review_content review_month  \
# 95   I learned absolutely NOTHING in this class.  E...          Mar
# 96   Nolan's class was a joke. If you are Catholic ...          Mar
# 97   Nolan teaches his "argumentation" class as if ...          Mar
# 98   I thought he was a very nice guy with interest...          Apr
# 99   I thought COMS 145 was really easy. It is a mu...          Dec
# 100  Mr Nolan is the man. This is class was really ...          Feb
# 101  It is hard not to think a lot of what Nolan sa...          Dec
# 102  Nolan might be the laziest teacher I have ever...          May
# 103  Besides always talking about his "Life Partner...          Aug
#
#      review_year student_class student_grade student_major student_standing  \
# 95          2009       SPC 145             B    General Ed        Sophomore
# 96          2009       SPC 145             B    General Ed           Junior
# 97          2009       SPC 145             B    General Ed        Sophomore
# 98          2009       SPC 145             A    General Ed         Freshman
# 99          2009       SPC 145             A    General Ed        Sophomore
# 100         2010       SPC 145             B    General Ed        Sophomore
# 101         2010       SPC 145           N/A    General Ed        Sophomore
# 102         2011       SPC 145           N/A    General Ed        Sophomore
# 103         2001       SPC 201             A    General Ed         Freshman
#
#      teacher_difficulties            teacher_field  teacher_name  \
# 95                   2.84    Communication Studies  Nolan, Frank
# 96                   2.84    Communication Studies  Nolan, Frank
# 97                   2.84    Communication Studies  Nolan, Frank
# 98                   2.84    Communication Studies  Nolan, Frank
# 99                   2.84    Communication Studies  Nolan, Frank
# 100                  2.84    Communication Studies  Nolan, Frank
# 101                  2.84    Communication Studies  Nolan, Frank
# 102                  2.84    Communication Studies  Nolan, Frank
# 103                  2.84    Communication Studies  Nolan, Frank
#
#      teacher_presentaion  teacher_rating
# 95                  2.92            3.01
# 96                  2.92            3.01
# 97                  2.92            3.01
# 98                  2.92            3.01
# 99                  2.92            3.01
# 100                 2.92            3.01
# 101                 2.92            3.01
# 102                 2.92            3.01
# 103                 2.92            3.01

# %% [markdown]
# ## Collecting Profile URLs

# %%
from bs4 import BeautifulSoup
import bs4
import requests
import time

def find_href(li):
    try:
        start = li.index("href=\"") + len("href=\"")
        end = li.index("\"", start )
        return li[start:end]
    except ValueError:
        return 0

# returns a list of all the profile URLs on Polyratings
def get_list(soup):
    
    profile_urls = []
    href = 0;
    
    profile_headers = soup.find_all("a", class_="no-link-highlight text-muted filterable")

    for header in profile_headers:
        href = find_href(str(header))
        if(href != 0):
            profile_urls.append(href.replace('"', ''))
    
    return profile_urls

# %%
# request the directory page
page = requests.get("http://polyratings.com/list.php") #directory of PolyRatings
soup = BeautifulSoup(page.text, "html.parser")

# %%
profile_urls = get_list(soup)

# %%
len(profile_urls)
# Out:
# 2478

# %% [markdown]
# ## Final Collection

# %%
#for url in profile_urls:
import pickle
import time
import sys

sys.setrecursionlimit(1000000000)

page = 1870

# evaluating one page at a time to handle errors if they arrise
for url in profile_urls[1870:]:
    prof = get_profile_df(url)
    if(prof is not None):
        name = prof.iloc[0]["teacher_name"].replace(', ', '_').lower()
        pickle.dump(prof, open("polyratings_profiles/" + name + ".pkl", "wb"))
    page += 1
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /opt/conda/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /opt/conda/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /opt/conda/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# /opt/conda/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /opt/conda/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /opt/conda/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /opt/conda/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /opt/conda/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /opt/conda/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# /opt/conda/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fc1b1dea898>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /opt/conda/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /opt/conda/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='polyratings.com', port=80): Max retries exceeded with url: /eval.php?profid=561 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fc1b1dea898>: Failed to establish a new connection: [Errno 111] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-220-2016065f25ef> in <module>()
#      10 # evaluating one page at a time to handle errors if they arrise
#      11 for url in profile_urls[1870:]:
# ---> 12     prof = get_profile_df(url)
#      13     if(prof is not None):
#      14         name = prof.iloc[0]["teacher_name"].replace(', ', '_').lower()
#
# <ipython-input-197-bfb4c47cb84e> in get_profile_df(profile_html)
#       2 def get_profile_df(profile_html):
#       3
# ----> 4     teacher_data = scrape_profile(profile_html)
#       5     (class_list, next_index) = get_classes(teacher_data)
#       6     if(next_index == 0):  # handles hidden pages
#
# <ipython-input-67-7977ea685c58> in scrape_profile(profile_html)
#       5 def scrape_profile(profile_html):
#       6
# ----> 7     teacher = requests.get(profile_html)
#       8     teacher_soup = BeautifulSoup(teacher.content, "html.parser")
#       9     return teacher_soup.find_all(text = True)
#
# /opt/conda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /opt/conda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /opt/conda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /opt/conda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='polyratings.com', port=80): Max retries exceeded with url: /eval.php?profid=561 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fc1b1dea898>: Failed to establish a new connection: [Errno 111] Connection refused',))
