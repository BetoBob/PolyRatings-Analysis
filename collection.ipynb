# %% [markdown]
# # I. Data Collection

# %%
import requests
from bs4 import BeautifulSoup

# converts profile page to list of line strings
def scrape_profile(profile_html):
    
    teacher = requests.get(profile_html)
    teacher_soup = BeautifulSoup(teacher.content, "html.parser")
    return teacher_soup.find_all(text = True)

# %%
# returns a list of classes taught
# by the teacher in the profile
def get_classes(data):
    
    # check for hidden/removed profiles
    if(data[110] == 
       "\nYou have requested an invalid professor evaluation; this could be because:\n"):
        return (None, 0)
    
    # check for N/A total scores (can not be used for machine learning model)
    # this also changes the offset values
    if(data[118][0:3] == 'N/A'):
        return (None, 0)
    
    classes = []
    i= 133; 
    
    first_class = data[133]
    classes.append(first_class)
    next_class = data[137]
    
    while(next_class != '\n'):
        classes.append(next_class)
        i += 4
        next_class = data[i]
    
    if(len(classes) == 1):
        return (classes, i + 7)
    
    return(classes, i + 3)

# %%
# collect the review information here
# returns a DataFrame of the data
import pandas as pd

def get_reviews(data, class_list, review_index):
    
    standings = ["Freshman", "Sophomore", "Junior", "Senior", "5th Year Senior", "5th/6th Year Senior", "Graduate Student"]
    
    rank = { "Freshman": 0, "Sophomore": 1, "Junior": 2, "Senior": 3, "5th Year Senior": 4, "5th/6th Year Senior": 4, "Graduate Student": 5}
    
    grades = { 'A': 4, 'B': 3, 'C': 2, 'D': 1, 'F': 0, 'N/A': None, 'Credit': None, 'No Credit': None, 'Withdrawn': None }
    
    reviews = { 'class': [], 'class_abrv': [], 'class_number': [], 
               'teacher_name': [], 'teacher_field': [], 'teacher_rating': [], 'teacher_difficulties': [], 'teacher_presentaion': [],
               'student_standing': [], 'student_rank': [], 'student_grade': [], 'student_gpa': [], 'student_major': [], 
               'review_month': [], 'review_year': [], 'review_content': [] }
    
    while(review_index < len(data)):
        
        # class information
        if(data[review_index] in class_list):
            reviews["class"].append(data[review_index])
            review_index += 3
        else:
            reviews["class"].append(reviews["class"][-1])
        
        student_class = reviews["class"][-1].split()
        reviews["class_abrv"].append(student_class[0])
        reviews["class_number"].append(int(student_class[1]))
        
        # teacher information
        reviews["teacher_name"].append(data[111])
        reviews["teacher_field"].append(data[117])
        reviews["teacher_rating"].append(float(data[118].split()[-1][0:4]))
        reviews["teacher_difficulties"].append(float(data[120].split()[-1])) # recognizes student difficulties
        reviews["teacher_presentaion"].append(float(data[121].split()[-1]))  
        
        # student information
        standing = data[review_index].replace("\n", '')
        reviews["student_standing"].append(standing)
        reviews["student_rank"].append(rank[standing])
        grade_letter = data[review_index + 1].replace("\n", '')
        reviews["student_grade"].append(grade_letter)
        reviews["student_gpa"].append(grades[grade_letter])
        reviews["student_major"].append(data[review_index + 2].replace("\n", ''))
        
        # review information
        time = data[review_index + 3].replace("\n", '').split()
        reviews["review_month"].append(time[0])
        reviews["review_year"].append(int(time[1]))
        
        review_index += 6 # offset to the beginning of the review

        review = ""       # default review is blank to account for empty reviews
        
        review_append = data[review_index].replace("\n",'').replace('\r', '')

        while((review_append not in class_list) and (review_append not in standings)):    #reviews are deliminated by class name
            
            if(review_append != ""):
                review = review + review_append
                
            review_index += 1
            
            if(review_index == (len(data) - 1)):
                reviews["review_content"].append(review)
                return pd.DataFrame(data = reviews)
            
            review_append = data[review_index].replace("\n",'').replace('\r', '')

        reviews["review_content"].append(review)

# %%
# returns a dataframe of a Polyrating's profile page
def get_profile_df(profile_html):

    teacher_data = scrape_profile(profile_html)
    (class_list, next_index) = get_classes(teacher_data)
    if(next_index == 0):  # handles hidden pages
        return None
    return get_reviews(teacher_data, class_list, next_index)

# %% [markdown]
# ## Example Profile Pages: Severus Snape

# %%
snape = get_profile_df("http://polyratings.com/eval.php?profid=3485")

# %%
snape
# Out:
#        class class_abrv  class_number  \
# 0   CHEM 101       CHEM           101
# 1   CHEM 110       CHEM           110
# 2   CHEM 124       CHEM           124
# 3   CHEM 124       CHEM           124
# 4   CHEM 125       CHEM           125
# 5   CHEM 125       CHEM           125
# 6   CHEM 129       CHEM           129
# 7   CHEM 202       CHEM           202
# 8   CHEM 211       CHEM           211
# 9   CHEM 216       CHEM           216
# 10  CHEM 242       CHEM           242
# 11  CHEM 394       CHEM           394
#
#                                        review_content review_month  \
# 0                        Snape, Snape, Severus Snape.          May
# 1   This professor is the most amazing teacher in ...          Mar
# 2   I tried really hard in his class but he seemed...          May
# 3   Very cramped handwriting, difficult to read on...          Jan
# 4   Coming in to the class I had heard some things...          Jan
# 5   I really wanted to get him for defense against...          May
# 6   Prof. Snape knows his chemistry, but seems per...          Jun
# 7   Professor Snape is a fantastic professor. Bare...          Jan
# 8   He can teach you how to bewitch the mind, and ...          Mar
# 9                                 I miss him. Always.          Jan
# 10  Professor Snape really knows his stuff. At fir...          Jan
# 11  At first he was really scary and intimidating....          Feb
#
#     review_year  student_gpa student_grade       student_major  student_rank  \
# 0          2014          3.0             B          General Ed             0
# 1          2014          4.0             A            Elective             0
# 2          2015          1.0             D    Required (Major)             0
# 3          2018          2.0             C  Required (Support)             0
# 4          2015          2.0             C            Elective             1
# 5          2016          3.0             B    Required (Major)             1
# 6          2015          2.0             C  Required (Support)             0
# 7          2018          4.0             A          General Ed             1
# 8          2014          3.0             B          General Ed             0
# 9          2016          3.0             B    Required (Major)             1
# 10         2016          1.0             D          General Ed             1
# 11         2014          NaN           N/A    Required (Major)             0
#
#    student_standing  teacher_difficulties                 teacher_field  \
# 0          Freshman                  2.33    Chemistry and Biochemistry
# 1          Freshman                  2.33    Chemistry and Biochemistry
# 2          Freshman                  2.33    Chemistry and Biochemistry
# 3          Freshman                  2.33    Chemistry and Biochemistry
# 4         Sophomore                  2.33    Chemistry and Biochemistry
# 5         Sophomore                  2.33    Chemistry and Biochemistry
# 6          Freshman                  2.33    Chemistry and Biochemistry
# 7         Sophomore                  2.33    Chemistry and Biochemistry
# 8          Freshman                  2.33    Chemistry and Biochemistry
# 9         Sophomore                  2.33    Chemistry and Biochemistry
# 10        Sophomore                  2.33    Chemistry and Biochemistry
# 11         Freshman                  2.33    Chemistry and Biochemistry
#
#       teacher_name  teacher_presentaion  teacher_rating
# 0   Snape, Severus                 3.33            3.17
# 1   Snape, Severus                 3.33            3.17
# 2   Snape, Severus                 3.33            3.17
# 3   Snape, Severus                 3.33            3.17
# 4   Snape, Severus                 3.33            3.17
# 5   Snape, Severus                 3.33            3.17
# 6   Snape, Severus                 3.33            3.17
# 7   Snape, Severus                 3.33            3.17
# 8   Snape, Severus                 3.33            3.17
# 9   Snape, Severus                 3.33            3.17
# 10  Snape, Severus                 3.33            3.17
# 11  Snape, Severus                 3.33            3.17

# %% [markdown]
# ## Edge Case Example: One Review

# %%
get_profile_df("http://polyratings.com/eval.php?profid=468")
# Out:
#       class class_abrv  class_number  \
# 0  MATE 128       MATE           128
#
#                                       review_content review_month  \
# 0  What the guy/gal below said. Amen. I too took ...          Nov
#
#    review_year  student_gpa student_grade student_major  student_rank  \
# 0         2016            4             A      Elective             3
#
#   student_standing  teacher_difficulties             teacher_field  \
# 0           Senior                   0.0    Mechanical Engineering
#
#         teacher_name  teacher_presentaion  teacher_rating
# 0  Mussulman, Ronald                  1.0             2.0

# %% [markdown]
# ## Large Profile (106 Reviews)

# %%
get_profile_df("http://polyratings.com/eval.php?profid=482")[-10: -1]
# Out:
#        class class_abrv  class_number  \
# 96   SPC 145        SPC           145
# 97   SPC 145        SPC           145
# 98   SPC 145        SPC           145
# 99   SPC 145        SPC           145
# 100  SPC 145        SPC           145
# 101  SPC 145        SPC           145
# 102  SPC 145        SPC           145
# 103  SPC 145        SPC           145
# 104  SPC 201        SPC           201
#
#                                         review_content review_month  \
# 96   I learned absolutely NOTHING in this class.  E...          Mar
# 97   Nolan's class was a joke. If you are Catholic ...          Mar
# 98   Nolan teaches his "argumentation" class as if ...          Mar
# 99   I thought he was a very nice guy with interest...          Apr
# 100  I thought COMS 145 was really easy. It is a mu...          Dec
# 101  Mr Nolan is the man. This is class was really ...          Feb
# 102  It is hard not to think a lot of what Nolan sa...          Dec
# 103  Nolan might be the laziest teacher I have ever...          May
# 104  Besides always talking about his "Life Partner...          Aug
#
#      review_year  student_gpa student_grade student_major  student_rank  \
# 96          2009          3.0             B    General Ed             1
# 97          2009          3.0             B    General Ed             2
# 98          2009          3.0             B    General Ed             1
# 99          2009          4.0             A    General Ed             0
# 100         2009          4.0             A    General Ed             1
# 101         2010          3.0             B    General Ed             1
# 102         2010          NaN           N/A    General Ed             1
# 103         2011          NaN           N/A    General Ed             1
# 104         2001          4.0             A    General Ed             0
#
#     student_standing  teacher_difficulties            teacher_field  \
# 96         Sophomore                  2.84    Communication Studies
# 97            Junior                  2.84    Communication Studies
# 98         Sophomore                  2.84    Communication Studies
# 99          Freshman                  2.84    Communication Studies
# 100        Sophomore                  2.84    Communication Studies
# 101        Sophomore                  2.84    Communication Studies
# 102        Sophomore                  2.84    Communication Studies
# 103        Sophomore                  2.84    Communication Studies
# 104         Freshman                  2.84    Communication Studies
#
#      teacher_name  teacher_presentaion  teacher_rating
# 96   Nolan, Frank                 2.92            3.01
# 97   Nolan, Frank                 2.92            3.01
# 98   Nolan, Frank                 2.92            3.01
# 99   Nolan, Frank                 2.92            3.01
# 100  Nolan, Frank                 2.92            3.01
# 101  Nolan, Frank                 2.92            3.01
# 102  Nolan, Frank                 2.92            3.01
# 103  Nolan, Frank                 2.92            3.01
# 104  Nolan, Frank                 2.92            3.01

# %% [markdown]
# ## Collecting Profile URLs

# %%
from bs4 import BeautifulSoup
import bs4
import requests
import time

def find_href(li):
    try:
        start = li.index("href=\"") + len("href=\"")
        end = li.index("\"", start )
        return li[start:end]
    except ValueError:
        return 0

# returns a list of all the profile URLs on Polyratings
def get_list(soup):
    
    profile_urls = []
    href = 0;
    
    profile_headers = soup.find_all("a", class_="no-link-highlight text-muted filterable")

    for header in profile_headers:
        href = find_href(str(header))
        if(href != 0):
            profile_urls.append(href.replace('"', ''))
    
    return profile_urls

# %%
# request the directory page
page = requests.get("http://polyratings.com/list.php") #directory of PolyRatings
soup = BeautifulSoup(page.text, "html.parser")

# %%
profile_urls = get_list(soup)

# %%
len(profile_urls)
# Out:
# 2478

# %% [markdown]
# ## Final Collection

# %%
# beware! ~30 minutes
import pickle
import time
import sys

sys.setrecursionlimit(1000000000)

page = 0

# evaluating one page at a time to handle errors if they arise
for url in profile_urls:
    prof = get_profile_df(url)
    if(prof is not None):
        name = prof.iloc[0]["teacher_name"].replace(', ', '_').lower()
        prof.to_csv("polyratings_profiles/" + name + ".csv")
    page += 1
    time.sleep(0.1)

# %% [markdown]
# ## One Large DataFrame

# %%
import os
import pandas as pd

teacher_df = []

for teacher in os.listdir('polyratings_profiles'):
    path = "polyratings_profiles/" + teacher
    if(path.endswith(".csv")):
        teacher_df.append(pd.read_csv(path))

# %%
reviews = pd.concat(teacher_df)

# %%
reviews["student_gpa"] = reviews.student_gpa.astype("float")

# %%
reviews.dtypes
# Out:
# Unnamed: 0                int64
# class                    object
# class_abrv               object
# class_number              int64
# review_content           object
# review_month             object
# review_year               int64
# student_gpa             float64
# student_grade            object
# student_major            object
# student_rank              int64
# student_standing         object
# teacher_difficulties    float64
# teacher_field            object
# teacher_name             object
# teacher_presentaion     float64
# teacher_rating          float64
# dtype: object

# %%
reviews.to_csv("polyratings_reviews.csv")

# %% [markdown]
# ## Check

# %%
test = pd.read_csv("polyratings_reviews.csv")

# %%
test.drop(test[["Unnamed: 0", "Unnamed: 0.1"]], axis = 1)
# Out:
#           class class_abrv  class_number  \
# 0       CPE 215        CPE           215
# 1       CPE 215        CPE           215
# 2       CPE 215        CPE           215
# 3       CPE 215        CPE           215
# 4       CPE 215        CPE           215
# 5       CPE 215        CPE           215
# 6       CPE 215        CPE           215
# 7       CSC 317        CSC           317
# 8       CSC 317        CSC           317
# 9       CSC 317        CSC           317
# 10      CSC 317        CSC           317
# 11      CSC 317        CSC           317
# 12      CSC 317        CSC           317
# 13      CPE 357        CPE           357
# 14      CPE 453        CPE           453
# 15      CPE 453        CPE           453
# 16      CPE 453        CPE           453
# 17      CPE 453        CPE           453
# 18      CPE 453        CPE           453
# 19      CPE 453        CPE           453
# 20      CPE 453        CPE           453
# 21      CPE 453        CPE           453
# 22      CPE 453        CPE           453
# 23      CSC 453        CSC           453
# 24      CSC 453        CSC           453
# 25       SS 551         SS           551
# 26      ART 182        ART           182
# 27      ART 182        ART           182
# 28      ART 183        ART           183
# 29      GRC 258        GRC           258
# ...         ...        ...           ...
# 64990  ECON 222       ECON           222
# 64991  ECON 222       ECON           222
# 64992  ECON 222       ECON           222
# 64993  ECON 222       ECON           222
# 64994  ECON 222       ECON           222
# 64995  ECON 222       ECON           222
# 64996  ECON 222       ECON           222
# 64997  ECON 222       ECON           222
# 64998  ECON 222       ECON           222
# 64999  ECON 222       ECON           222
# 65000  ECON 222       ECON           222
# 65001  ECON 322       ECON           322
# 65002  ECON 322       ECON           322
# 65003  ECON 322       ECON           322
# 65004  ECON 322       ECON           322
# 65005  ECON 322       ECON           322
# 65006  ECON 323       ECON           323
# 65007  ECON 324       ECON           324
# 65008  ARCH 526       ARCH           526
# 65009  MATH 118       MATH           118
# 65010    TH 433         TH           433
# 65011  ASCI 224       ASCI           224
# 65012  ASCI 333       ASCI           333
# 65013  ASCI 333       ASCI           333
# 65014  ASCI 333       ASCI           333
# 65015  ASCI 333       ASCI           333
# 65016  ASCI 333       ASCI           333
# 65017  ASCI 333       ASCI           333
# 65018  ASCI 490       ASCI           490
# 65019  CRSC 552       CRSC           552
#
#                                           review_content review_month  \
# 0      he knows what he's talking about, he knows how...          Aug
# 1      In two years being here at Cal Poly, Dr Connel...          Aug
# 2      Connely's an excellent professor.  I've had hi...          Aug
# 3      This guy knows what he is talking about, and h...          Aug
# 4      I could go on and on about how great of a teac...          Dec
# 5      Dr. Connely is a great teacher and he conveys ...          Feb
# 6      Dr.Connely is the best teacher I've had for al...          Feb
# 7      you learn C and some unix stuff.  he has a nic...          Dec
# 8      Dr. Connely is one of the best professors I've...          Jan
# 9      CPE x317 was a worthwhile introduction to the ...          Mar
# 10     Dr. Connely presents material in a concise, lo...          Mar
# 11     Connely fucking rocks. Lectures present the ma...          Mar
# 12     AN AWESOME PEROFESSOR AND PERSON. Dr. Connely ...          Jun
# 13     [Note: CPE-357 was CPE-x317, but I took 357] G...          Mar
# 14     great attitude and good teacher... what more c...          Oct
# 15     Professor Connely is a nice man, a good lectur...          Dec
# 16     no real need to go on about connely. he's a no...          Apr
# 17     John may be a nice man, but he's a rather boor...          Nov
# 18     Let me throw my two cents about 317 and 453 wi...          Dec
# 19     I got a B, I got a D on one exam, a C- on anot...          Dec
# 20     Ok....the reviews prior pretty much say it all...          Dec
# 21     Dr. Connely is awesome!  He assigns 4 projects...          Dec
# 22     Too easy. Old guy that should be retired. 4 la...          Jun
# 23     Every CSC teacher should adopt Connely's attit...          Sep
# 24     This guy is strange.  For what he wants to tea...          Feb
# 25     Taking this instructor is like being in a Twil...          Nov
# 26     When I raised my hand in class she said "See m...          Dec
# 27     Enrica tries really hard to be a good teacher....          Jan
# 28     Enrica is the worst professor I have had at Po...          May
# 29     What the guy/gal below said. Amen. I too took ...          Nov
# ...                                                  ...          ...
# 64990  Dont Take him for Macro. He's usually a histor...          Jan
# 64991  I really like his class.  The tests, there are...          Jan
# 64992  Kersten was very knowledgable but boring as he...          Feb
# 64993  I only went to the first day of class, the fou...          Feb
# 64994  Kersten is probably one of the best lecturers,...          Dec
# 64995  I really liked this teacher. He thikns he is s...          Jan
# 64996  He was the worst teacher I have ever had. He c...          Jun
# 64997  He is pretty straight forward. The class is ou...          Jun
# 64998  Kersten is an overall good guy that knows his ...          Nov
# 64999  Kersten is awesome for 222. After the first fe...          Feb
# 65000  I didn't really study; tests and quizzes were ...          Aug
# 65001  OK.  He's a nice guy and tries to be funny whi...          Jun
# 65002  Someone below said that you better know everyt...          Mar
# 65003  DO NOT TAKE THIS CLASS UNLESS YOU ARE REQUIRED...          Apr
# 65004  I had Kersten for Econ 222 and Econ 322. I rea...          Dec
# 65005  Dope professor, definitely knows his stuff.  I...          Dec
# 65006  His lectures are pretty dry, but economic hist...          Aug
# 65007  This guy is alright. You have to read the book...          Jul
# 65008  During this entire quarter all I could think a...          Nov
# 65009  He is young undergrad teacher. He is a cool gu...          Nov
# 65010  Fine teacher, but a little dry in the presenta...          Nov
# 65011  I love this guy! He presents material interest...          Aug
# 65012  I love Mr. Lund!  He is an AWESOME lecture... ...          Aug
# 65013  In ASCI 333 Lund covered many aspects of the h...          Apr
# 65014  Mr. Lund is AWESOME!! i loved this class even ...          Aug
# 65015  Mr. Lund tries to do a good job with his class...          Oct
# 65016  Mr. Lund is a great proffesor.  He kept class ...          Mar
# 65017  Mr. Lund is awesome!   There is nothing more t...          Mar
# 65018  For those of you who never had the chance to t...          Jan
# 65019  What the guy/gal below said. Amen. I too took ...          Nov
#
#        review_year  student_gpa student_grade       student_major  \
# 0             2001          4.0             A    Required (Major)
# 1             2001          4.0             A    Required (Major)
# 2             2001          3.0             B    Required (Major)
# 3             2001          4.0             A    Required (Major)
# 4             1999          4.0             A  Required (Support)
# 5             2000          3.0             B  Required (Support)
# 6             2001          4.0             A  Required (Support)
# 7             2002          4.0             A    Required (Major)
# 8             2003          4.0             A            Elective
# 9             2003          3.0             B  Required (Support)
# 10            2003          4.0             A    Required (Major)
# 11            2003          3.0             B  Required (Support)
# 12            2003          3.0             B            Elective
# 13            2006          4.0             A    Required (Major)
# 14            2001          4.0             A    Required (Major)
# 15            2001          4.0             A    Required (Major)
# 16            2002          4.0             A    Required (Major)
# 17            2004          2.0             C    Required (Major)
# 18            2004          4.0             A    Required (Major)
# 19            2004          3.0             B    Required (Major)
# 20            2004          3.0             B    Required (Major)
# 21            2006          3.0             B    Required (Major)
# 22            2008          4.0             A    Required (Major)
# 23            2001          2.0             C    Required (Major)
# 24            2009          4.0             A    Required (Major)
# 25            2016          4.0             A  Required (Support)
# 26            2012          NaN     Withdrawn            Elective
# 27            2014          4.0             A    Required (Major)
# 28            2016          2.0             C    Required (Major)
# 29            2016          4.0             A  Required (Support)
# ...            ...          ...           ...                 ...
# 64990         2005          NaN           NaN  Required (Support)
# 64991         2005          3.0             B  Required (Support)
# 64992         2005          3.0             B    Required (Major)
# 64993         2005          3.0             B  Required (Support)
# 64994         2005          2.0             C  Required (Support)
# 64995         2006          3.0             B  Required (Support)
# 64996         2007          NaN           NaN          General Ed
# 64997         2007          4.0             A    Required (Major)
# 64998         2007          3.0             B          General Ed
# 64999         2008          4.0             A  Required (Support)
# 65000         2008          3.0             B  Required (Support)
# 65001         2004          1.0             D            Elective
# 65002         2006          3.0             B            Elective
# 65003         2007          1.0             D          General Ed
# 65004         2007          3.0             B    Required (Major)
# 65005         2007          3.0             B  Required (Support)
# 65006         2001          4.0             A    Required (Major)
# 65007         2007          3.0             B            Elective
# 65008         2016          4.0             A    Required (Major)
# 65009         2011          4.0             A  Required (Support)
# 65010         2016          2.0             C            Elective
# 65011         2004          4.0             A    Required (Major)
# 65012         2001          4.0             A            Elective
# 65013         2002          3.0             B  Required (Support)
# 65014         2002          4.0             A  Required (Support)
# 65015         2002          NaN           NaN            Elective
# 65016         2003          4.0             A    Required (Major)
# 65017         2003          4.0             A  Required (Support)
# 65018         2006          NaN        Credit            Elective
# 65019         2016          2.0             C    Required (Major)
#
#        student_rank  student_standing  teacher_difficulties  \
# 0                 1         Sophomore                  3.64
# 1                 1         Sophomore                  3.64
# 2                 2            Junior                  3.64
# 3                 1         Sophomore                  3.64
# 4                 2            Junior                  3.64
# 5                 4   5th Year Senior                  3.64
# 6                 1         Sophomore                  3.64
# 7                 2            Junior                  3.64
# 8                 3            Senior                  3.64
# 9                 2            Junior                  3.64
# 10                1         Sophomore                  3.64
# 11                3            Senior                  3.64
# 12                3            Senior                  3.64
# 13                2            Junior                  3.64
# 14                3            Senior                  3.64
# 15                3            Senior                  3.64
# 16                2            Junior                  3.64
# 17                4   5th Year Senior                  3.64
# 18                2            Junior                  3.64
# 19                3            Senior                  3.64
# 20                4   5th Year Senior                  3.64
# 21                3            Senior                  3.64
# 22                2            Junior                  3.64
# 23                2            Junior                  3.64
# 24                2            Junior                  3.64
# 25                5  Graduate Student                  3.64
# 26                3            Senior                  1.25
# 27                0          Freshman                  1.25
# 28                0          Freshman                  1.25
# 29                5  Graduate Student                  1.25
# ...             ...               ...                   ...
# 64990             1         Sophomore                  2.33
# 64991             0          Freshman                  2.33
# 64992             0          Freshman                  2.33
# 64993             0          Freshman                  2.33
# 64994             0          Freshman                  2.33
# 64995             0          Freshman                  2.33
# 64996             0          Freshman                  2.33
# 64997             0          Freshman                  2.33
# 64998             0          Freshman                  2.33
# 64999             1         Sophomore                  2.33
# 65000             0          Freshman                  2.33
# 65001             3            Senior                  2.33
# 65002             2            Junior                  2.33
# 65003             3            Senior                  2.33
# 65004             2            Junior                  2.33
# 65005             2            Junior                  2.33
# 65006             2            Junior                  2.33
# 65007             1         Sophomore                  2.33
# 65008             4   5th Year Senior                  2.33
# 65009             0          Freshman                  2.00
# 65010             3            Senior                  2.00
# 65011             0          Freshman                  3.13
# 65012             2            Junior                  3.13
# 65013             0          Freshman                  3.13
# 65014             0          Freshman                  3.13
# 65015             3            Senior                  3.13
# 65016             1         Sophomore                  3.13
# 65017             0          Freshman                  3.13
# 65018             4   5th Year Senior                  3.13
# 65019             5  Graduate Student                  3.13
#
#             teacher_field      teacher_name  teacher_presentaion  \
# 0        Computer Science     Connely, John                 3.45
# 1        Computer Science     Connely, John                 3.45
# 2        Computer Science     Connely, John                 3.45
# 3        Computer Science     Connely, John                 3.45
# 4        Computer Science     Connely, John                 3.45
# 5        Computer Science     Connely, John                 3.45
# 6        Computer Science     Connely, John                 3.45
# 7        Computer Science     Connely, John                 3.45
# 8        Computer Science     Connely, John                 3.45
# 9        Computer Science     Connely, John                 3.45
# 10       Computer Science     Connely, John                 3.45
# 11       Computer Science     Connely, John                 3.45
# 12       Computer Science     Connely, John                 3.45
# 13       Computer Science     Connely, John                 3.45
# 14       Computer Science     Connely, John                 3.45
# 15       Computer Science     Connely, John                 3.45
# 16       Computer Science     Connely, John                 3.45
# 17       Computer Science     Connely, John                 3.45
# 18       Computer Science     Connely, John                 3.45
# 19       Computer Science     Connely, John                 3.45
# 20       Computer Science     Connely, John                 3.45
# 21       Computer Science     Connely, John                 3.45
# 22       Computer Science     Connely, John                 3.45
# 23       Computer Science     Connely, John                 3.45
# 24       Computer Science     Connely, John                 3.45
# 25       Computer Science     Connely, John                 3.45
# 26         Art and Design  Costello, Enrica                 0.75
# 27         Art and Design  Costello, Enrica                 0.75
# 28         Art and Design  Costello, Enrica                 0.75
# 29         Art and Design  Costello, Enrica                 0.75
# ...                   ...               ...                  ...
# 64990           Economics      Kersten, Tim                 2.58
# 64991           Economics      Kersten, Tim                 2.58
# 64992           Economics      Kersten, Tim                 2.58
# 64993           Economics      Kersten, Tim                 2.58
# 64994           Economics      Kersten, Tim                 2.58
# 64995           Economics      Kersten, Tim                 2.58
# 64996           Economics      Kersten, Tim                 2.58
# 64997           Economics      Kersten, Tim                 2.58
# 64998           Economics      Kersten, Tim                 2.58
# 64999           Economics      Kersten, Tim                 2.58
# 65000           Economics      Kersten, Tim                 2.58
# 65001           Economics      Kersten, Tim                 2.58
# 65002           Economics      Kersten, Tim                 2.58
# 65003           Economics      Kersten, Tim                 2.58
# 65004           Economics      Kersten, Tim                 2.58
# 65005           Economics      Kersten, Tim                 2.58
# 65006           Economics      Kersten, Tim                 2.58
# 65007           Economics      Kersten, Tim                 2.58
# 65008           Economics      Kersten, Tim                 2.58
# 65009         Mathematics    Comelli, Isaac                 2.50
# 65010         Mathematics    Comelli, Isaac                 2.50
# 65011      Animal Science     Lund, Michael                 3.63
# 65012      Animal Science     Lund, Michael                 3.63
# 65013      Animal Science     Lund, Michael                 3.63
# 65014      Animal Science     Lund, Michael                 3.63
# 65015      Animal Science     Lund, Michael                 3.63
# 65016      Animal Science     Lund, Michael                 3.63
# 65017      Animal Science     Lund, Michael                 3.63
# 65018      Animal Science     Lund, Michael                 3.63
# 65019      Animal Science     Lund, Michael                 3.63
#
#        teacher_rating
# 0                3.41
# 1                3.41
# 2                3.41
# 3                3.41
# 4                3.41
# 5                3.41
# 6                3.41
# 7                3.41
# 8                3.41
# 9                3.41
# 10               3.41
# 11               3.41
# 12               3.41
# 13               3.41
# 14               3.41
# 15               3.41
# 16               3.41
# 17               3.41
# 18               3.41
# 19               3.41
# 20               3.41
# 21               3.41
# 22               3.41
# 23               3.41
# 24               3.41
# 25               3.41
# 26               1.00
# 27               1.00
# 28               1.00
# 29               1.00
# ...               ...
# 64990            2.40
# 64991            2.40
# 64992            2.40
# 64993            2.40
# 64994            2.40
# 64995            2.40
# 64996            2.40
# 64997            2.40
# 64998            2.40
# 64999            2.40
# 65000            2.40
# 65001            2.40
# 65002            2.40
# 65003            2.40
# 65004            2.40
# 65005            2.40
# 65006            2.40
# 65007            2.40
# 65008            2.40
# 65009            2.50
# 65010            2.50
# 65011            3.50
# 65012            3.50
# 65013            3.50
# 65014            3.50
# 65015            3.50
# 65016            3.50
# 65017            3.50
# 65018            3.50
# 65019            3.50
#
# [65020 rows x 16 columns]
